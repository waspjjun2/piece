# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <!-- Gan에서의 학습) Discriminator가 담당한다고 봐야 한다.(binary classification)
#
# Dstn으로 훈련!
#
# log(D(x)) : 진짜를 진짜라고 구분하지 못하는 오차
# log(1 - D(G(x))) : 가짜를 가짜라고 구분하지 못하는 오차
# 진짜 real : 1 / 가짜 : 0
# z : Gaussian Noise -->

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <!-- #2. Discriminator(labeled data로 지도학습한 분류기 모델)로 판단하는 것이므로
#
# #3. Generator가 다양성을 잃는 경우, Generator와 Discriminator가 균형있게
#
# 학습이 되지 않는 경우 -->

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# encoding시켜 feature vector로 reshape 시킴
# 2배씩 차원을 늘려나감과 동시에 feature vector를 반으로 축소
# 마지막에는 feature vector를 3차원으로 만들어준다.

# %% [markdown]
# ![image.png](attachment:0b10c003-c2cb-4905-aa44-835f8efb5ab1.png)

# %% [markdown]
# ![image.png](attachment:c4745acc-11df-4642-8d11-c7257d8a4a26.png)

# %% [markdown]
# <!-- fully connected layer : 완전 연결 층
# ## D :  784 -> 128 -> relu -> 128 -> sigmoid ( binary classification )
# ## G : 100 -> 128 -> relu -> 784 -> tanh (-1, 1)
# ## G에서 나온 결과값을 G로 넣음
# MNIST를 flatten한 real data 10개와 G 생성 data 10개를 넣어줌 -->

# %% [markdown]
# ![image.png](attachment:b306a6b7-6475-44c7-b067-65626246fadf.png)

# %% [markdown]
# ![image.png](attachment:afe1f16d-20e7-43da-8474-d20297cb5672.png)

# %% [markdown]
# ![image.png](attachment:f010deb1-f8be-419c-98dc-bc6fd667abb1.png)

# %% [markdown]
# <!-- D(G(Z)) : 가짜를 진짜라고 판단하지 못했을 때의 오차
# 파란색 : Generator / 빨간색 : Discriminator  # ????
# Discriminator에서 다 1이 나올 때까지 학습을 해야한다! -->

# %% [markdown]
# ## dcGAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# encoding 이후 conv! -> color image

# %% [markdown]
# ![image.png](attachment:image.png)
# color image -> flatten -> number(0~1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# maxpooling 대신 strided convolution
#
# stride = 2 로 upsampling을 학습했다고 볼 수 있음
#
# upsampling보다 convolution stride 하는 추세?
# cf . upsampling ( interpolation 기반 )

# %% [markdown]
# ....
